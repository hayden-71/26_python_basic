# %% [markdown]
# ### 숫자형

# %%
# 양의 정수
567

# %%
# 음의 정수
-942

# %%
# 실수
3.14159

# %%
# 지수 표기법
1.2e3  # 1.2 * 10^3 = 1200.0
1.2e-3 # 1.2 * 10^-3 = 0.0012

# %%
# 8진수: 0o 또는 0O로 시작
0o123 # 1 * 8^2 + 2 * 8^1 + 3 * 8^0 = 83

# %%
# 16진수: 0x 또는 0X로 시작
0x1A3F # 1 * 16^3 + 10 * 16^2 + 3 * 16^1 + 15 * 16^0 = 6719

# %% [markdown]
# ### 연산

# %%
# 사칙연산: 더하기
3 + 5

# %%
# 사칙연산: 빼기
10 - 4

# %%
# 사칙연산: 곱하기
6 * 7

# %%
# 사칙연산: 나누기
22 / 8
# Out:
# 2.75

# %%
# 나머지 연산 -> 홀수냐 짝수냐 판별할 때 많이 쓰임
22 % 8
# Out:
# 6

# %%
# 몫 연산 -> 최대 몇 명한테 줄 수 있냐 계산할 때
22 // 8
# Out:
# 2

# %%
# 제곱근 연산
5 ** 2
# Out:
# 25

# %%
# EOD.
